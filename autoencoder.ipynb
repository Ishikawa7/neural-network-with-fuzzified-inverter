# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objects as go
sns.set()

# %%
# a1a1 = tf.reshape(inputs[0],shape=(1,1))   #1
# a1a2 = tf.reshape(inputs[1],shape=(1,1))   #2 
# a1a2a2 = tf.reshape(inputs[2],shape=(1,1)) #3
# a1a2a1 = tf.reshape(inputs[3],shape=(1,1)) #4
# a2a2 = tf.reshape(inputs[4],shape=(1,1))   #5
# a2a1 = tf.reshape(inputs[5],shape=(1,1))   #6
# a2a1a1 = tf.reshape(inputs[6],shape=(1,1)) #7
# a2a1a2 = tf.reshape(inputs[7],shape=(1,1)) #8

# to_hidden = []
# to_hidden.append((tf.concat([a1a2a2, a2a2], axis = 1)))   #["TrRi"] [3,5]
# to_hidden.append((tf.concat([a1a2a1, a2a1], axis = 1)))   #["RiTr"] [4,6] 
# to_hidden.append((tf.concat([a1a1, a2a1], axis = 1)))     #["Plu"]  [1,6] 
# to_hidden.append((tf.concat([a1a2, a1a2a2], axis = 1)))   #["TTra"] [2,3] 
# to_hidden.append((tf.concat([a2a1, a2a1a1], axis = 1)))   #["TTrb"] [6,7] 
# to_hidden.append((tf.concat([a1a2, a2a1], axis = 1)))     #["Tr"]   [2,6]
# to_hidden.append((tf.concat([a1a2a1, a2a1a2], axis = 1))) #["MeTr"] [4,8] 
# to_hidden.append((tf.concat([a1a2a1, a1a2], axis = 1)))   #["MoTr"] [4,2] 
# to_hidden.append((tf.concat([a1a1, a1a2a1], axis = 1)))   #["RiRi"] [1,4] 
# to_hidden.append((tf.concat([a1a1, a1a2], axis = 1)))     #["MoFo"] [1,2] 
# to_hidden.append((tf.concat([a1a2a2, a1a2a1], axis = 1))) #["MMof"] [3,4] 
# to_hidden.append((tf.concat([a1a1, a1a2a2], axis = 1)))   #["MoRi"] [1,3] 
# to_hidden.append((tf.concat([a1a2a2, a2a1a1], axis = 1))) #["MeRi"] [3,7] 
# to_hidden.append((tf.concat([a1a1, a2a2], axis = 1)))     #["Ri"]   [1,5]

# %%
# create an autoencoder using tensorflow functional API
input_dim = 8
encoding_dim = 15
# input layer
input_a1a1 = keras.Input(shape=(1, 1))
input_a1a2 = keras.Input(shape=(1, 1))
input_a1a2a2 = keras.Input(shape=(1, 1))
input_a1a2a1 = keras.Input(shape=(1, 1))
input_a2a2 = keras.Input(shape=(1, 1))
input_a2a1 = keras.Input(shape=(1, 1))
input_a2a1a1 = keras.Input(shape=(1, 1))
input_a2a1a2 = keras.Input(shape=(1, 1))

concatenate_a1a2a2_a2a2 = keras.layers.concatenate([input_a1a2a2, input_a2a2], axis = 1)        #["TrRi"] [3,5]  
concatenate_a1a2a1_a2a1 = keras.layers.concatenate([input_a1a2a1, input_a2a1], axis = 1)        #["RiTr"] [4,6]    
concatenate_a1a1_a2a1 = keras.layers.concatenate([input_a1a1, input_a2a1], axis = 1)            #["Plu"]  [1,6]
concatenate_a1a2_a1a2a2 = keras.layers.concatenate([input_a1a2, input_a1a2a2], axis = 1)        #["TTra"] [2,3]    
concatenate_a2a1_a2a1a1 = keras.layers.concatenate([input_a2a1, input_a2a1a1], axis = 1)        #["TTrb"] [6,7]    
concatenate_a1a2_a2a1 = keras.layers.concatenate([input_a1a2, input_a2a1], axis = 1)            #["Tr"]   [2,6]
concatenate_a1a2a1_a2a1a2 = keras.layers.concatenate([input_a1a2a1, input_a2a1a2], axis = 1)    #["MeTr"] [4,8]        
concatenate_a1a2a1_a1a2 = keras.layers.concatenate([input_a1a2a1, input_a1a2], axis = 1)        #["MoTr"] [4,2]    
concatenate_a1a1_a1a2a1 = keras.layers.concatenate([input_a1a1, input_a1a2a1], axis = 1)        #["RiRi"] [1,4]    
concatenate_a1a1_a1a2 = keras.layers.concatenate([input_a1a1, input_a1a2], axis = 1)            #["MoFo"] [1,2]
concatenate_a1a2a2_a1a2a1 = keras.layers.concatenate([input_a1a2a2, input_a1a2a1], axis = 1)    #["MMof"] [3,4]        
concatenate_a1a1_a1a2a2 = keras.layers.concatenate([input_a1a1, input_a1a2a2], axis = 1)        #["MoRi"] [1,3]    
concatenate_a1a2a2_a2a1a1 = keras.layers.concatenate([input_a1a2a2, input_a2a1a1], axis = 1)    #["MeRi"] [3,7]        
concatenate_a1a1_a2a2 = keras.layers.concatenate([input_a1a1, input_a2a2], axis = 1)            #["Ri"]   [1,5]

hidden_TrRi = layers.Dense(1, activation="tanh", name = "TrRi_hidden")(concatenate_a1a2a2_a2a2)
hidden_RiTr = layers.Dense(1, activation="tanh", name = "RiTr_hidden")(concatenate_a1a2a1_a2a1)
hidden_Plu = layers.Dense(1, activation="tanh", name = "Plu_hidden")(concatenate_a1a1_a2a1)
hidden_TTra = layers.Dense(1, activation="tanh", name = "TTra_hidden")(concatenate_a1a2_a1a2a2)
hidden_TTrb = layers.Dense(1, activation="tanh", name = "TTrb_hidden")(concatenate_a2a1_a2a1a1)
hidden_Tr = layers.Dense(1, activation="tanh", name = "Tr_hidden")(concatenate_a1a2_a2a1)
hidden_MeTr = layers.Dense(1, activation="tanh", name= "MeTr_hidden")(concatenate_a1a2a1_a2a1a2)
hidden_MoTr = layers.Dense(1, activation="tanh", name= "MoTr_hidden")(concatenate_a1a2a1_a1a2)
hidden_RiRi = layers.Dense(1, activation="tanh", name= "RiRi_hidden")(concatenate_a1a1_a1a2a1)
hidden_MoFo = layers.Dense(1, activation="tanh", name= "MoFo_hidden")(concatenate_a1a1_a1a2)
hidden_MMof = layers.Dense(1, activation="tanh", name= "MMof_hidden")(concatenate_a1a2a2_a1a2a1)
hidden_MoRi = layers.Dense(1, activation="tanh", name= "MoRi_hidden")(concatenate_a1a1_a1a2a2)
hidden_MeRi = layers.Dense(1, activation="tanh", name= "MeRi_hidden")(concatenate_a1a2a2_a2a1a1)
hidden_Ri = layers.Dense(1, activation="tanh", name ="Ri_hidden")(concatenate_a1a1_a2a2)

concatenate_a1a1 = keras.layers.concatenate([hidden_Plu, hidden_RiRi, hidden_MoFo, hidden_MoRi, hidden_Ri], axis = 1)
concatenate_a1a2 = keras.layers.concatenate([hidden_TTra, hidden_Tr, hidden_MoTr, hidden_MoFo], axis = 1)
concatenate_a1a2a1 = keras.layers.concatenate([hidden_RiTr, hidden_MeTr, hidden_MoTr, hidden_RiRi], axis = 1)
concatenate_a1a2a2 = keras.layers.concatenate([hidden_TrRi, hidden_TTra, hidden_MMof, hidden_MeRi], axis = 1)
concatenate_a2a1 = keras.layers.concatenate([hidden_TTrb, hidden_Tr, hidden_MeTr, hidden_Ri], axis = 1)
concatenate_a2a1a1 = keras.layers.concatenate([hidden_TTrb, hidden_MeRi, hidden_RiRi], axis = 1)
concatenate_a2a1a2 = keras.layers.concatenate([hidden_MeTr, hidden_MeRi], axis = 1)
concatenate_a2a2 = keras.layers.concatenate([hidden_TrRi, hidden_Ri], axis = 1)

output_a1a1 = layers.Dense(1, activation="tanh", name = "a1a1_output")(concatenate_a1a1)
output_a1a2 = layers.Dense(1, activation="tanh", name = "a1a2_output")(concatenate_a1a2)
output_a1a2a1 = layers.Dense(1, activation="tanh", name = "a1a2a1_output")(concatenate_a1a2a1)
output_a1a2a2 = layers.Dense(1, activation="tanh", name = "a1a2a2_output")(concatenate_a1a2a2)
output_a2a1 = layers.Dense(1, activation="tanh", name = "a2a1_output")(concatenate_a2a1)
output_a2a1a1 = layers.Dense(1, activation="tanh", name = "a2a1a1_output")(concatenate_a2a1a1)
output_a2a1a2 = layers.Dense(1, activation="tanh", name = "a2a1a2_output")(concatenate_a2a1a2)
output_a2a2 = layers.Dense(1, activation="tanh", name = "a2a2_output")(concatenate_a2a2)

# autoencoder
autoencoder = keras.Model(inputs=[input_a1a1, input_a1a2, input_a1a2a1, input_a1a2a2, input_a2a1, input_a2a1a1, input_a2a1a2, input_a2a2], outputs=[output_a1a1, output_a1a2, output_a1a2a1, output_a1a2a2, output_a2a1, output_a2a1a1, output_a2a1a2, output_a2a2])

# %%
autoencoder.compile(optimizer='adam', loss='mse', run_eagerly=False)

# %%
# Model input
a1a1 = 0.01 #1
a1a2 = 0.00 #2 
a1a2a2 = 0.03 #3
a1a2a1 = 0.22 #4
a2a2 = 0.87 #5
a2a1 = 0.26 #6
a2a1a1 = 0.42 #7
a2a1a2 = 0.16 #8

# transform the input in numpy arrays
a1a1 = np.array(a1a1).reshape(1,1)
a1a2 = np.array(a1a2).reshape(1,1)
a1a2a2 = np.array(a1a2a2).reshape(1,1)
a1a2a1 = np.array(a1a2a1).reshape(1,1)
a2a2 = np.array(a2a2).reshape(1,1)
a2a1 = np.array(a2a1).reshape(1,1)
a2a1a1 = np.array(a2a1a1).reshape(1,1)
a2a1a2 = np.array(a2a1a2).reshape(1,1)

# Model fit
history = autoencoder.fit([a1a1, a1a2, a1a2a1, a1a2a2, a2a1, a2a1a1, a2a1a2, a2a2], [a1a1, a1a2, a1a2a1, a1a2a2, a2a1, a2a1a1, a2a1a2, a2a2], epochs=1000, batch_size=1)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 4s 4s/step - loss: 1.3682 - a1a1_output_loss: 0.0367 - a1a2_output_loss: 0.0027 - a1a2a1_output_loss: 0.0482 - a1a2a2_output_loss: 0.0444 - a2a1_output_loss: 0.1681 - a2a1a1_output_loss: 0.2207 - a2a1a2_output_loss: 0.0979 - a2a2_output_loss: 0.7495
# Epoch 2/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3603 - a1a1_output_loss: 0.0364 - a1a2_output_loss: 0.0025 - a1a2a1_output_loss: 0.0477 - a1a2a2_output_loss: 0.0440 - a2a1_output_loss: 0.1669 - a2a1a1_output_loss: 0.2195 - a2a1a2_output_loss: 0.0961 - a2a2_output_loss: 0.7470
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3523 - a1a1_output_loss: 0.0361 - a1a2_output_loss: 0.0024 - a1a2a1_output_loss: 0.0473 - a1a2a2_output_loss: 0.0436 - a2a1_output_loss: 0.1657 - a2a1a1_output_loss: 0.2183 - a2a1a2_output_loss: 0.0943 - a2a2_output_loss: 0.7446
# Epoch 4/1000
# ...

# %%
# dataframe with the results
df_results = pd.DataFrame(history.history)
df_results
# Out:
#          loss  a1a1_output_loss  a1a2_output_loss  a1a2a1_output_loss  \
# 0    1.368249          0.036687          0.002656        4.820056e-02
# 1    1.360252          0.036411          0.002523        4.773980e-02
# 2    1.352309          0.036136          0.002402        4.728180e-02
# 3    1.344419          0.035864          0.002291        4.682662e-02
# 4    1.336580          0.035594          0.002188        4.637429e-02
# ..        ...               ...               ...                 ...
# 995  0.029051          0.000843          0.000021        4.712342e-13
# 996  0.028959          0.000839          0.000021        4.532763e-13
# 997  0.028869          0.000836          0.000021        4.433398e-13
# 998  0.028778          0.000832          0.000021        4.259371e-13
# 999  0.028688          0.000829          0.000021        4.044820e-13
#
#      a1a2a2_output_loss  a2a1_output_loss  a2a1a1_output_loss  \
# 0              0.044407          0.168145            0.220723
# ...

# %%
# plot the losses with plotly express
fig = px.line(df_results, x=df_results.index, y=df_results.columns, title= "losses")
fig.show()

# %%
# extract the weights of the hidden layers
W_hidden_Plu = autoencoder.get_layer("Plu_hidden").get_weights()[0][0][0]
W_hidden_TTra = autoencoder.get_layer("TTra_hidden").get_weights()[0][0][0]
W_hidden_TTrb = autoencoder.get_layer("TTrb_hidden").get_weights()[0][0][0]
W_hidden_Tr = autoencoder.get_layer("Tr_hidden").get_weights()[0][0][0]
W_hidden_RiTr = autoencoder.get_layer("RiTr_hidden").get_weights()[0][0][0]
W_hidden_MoTr = autoencoder.get_layer("MoTr_hidden").get_weights()[0][0][0]
W_hidden_MeTr = autoencoder.get_layer("MeTr_hidden").get_weights()[0][0][0]
w_hidden_MoTr = autoencoder.get_layer("MoTr_hidden").get_weights()[0][0][0]
W_hidden_TrRi = autoencoder.get_layer("TrRi_hidden").get_weights()[0][0][0]
W_hidden_RiRi = autoencoder.get_layer("RiRi_hidden").get_weights()[0][0][0]
W_hidden_MeRi = autoencoder.get_layer("MeRi_hidden").get_weights()[0][0][0]
W_hidden_MMof = autoencoder.get_layer("MMof_hidden").get_weights()[0][0][0]
W_hidden_Ri = autoencoder.get_layer("Ri_hidden").get_weights()[0][0][0]

# put the weights in a dataframe
df_weights_hidden = pd.DataFrame([W_hidden_Plu, W_hidden_TTra, W_hidden_TTrb, W_hidden_Tr, W_hidden_RiTr, W_hidden_MoTr, W_hidden_MeTr, w_hidden_MoTr, W_hidden_TrRi, W_hidden_RiRi, W_hidden_MeRi, W_hidden_MMof, W_hidden_Ri])
df_weights_hidden.index = ["W_hidden_Plu", "W_hidden_TTra", "W_hidden_TTrb", "W_hidden_Tr", "W_hidden_RiTr", "W_hidden_MoTr", "W_hidden_MeTr", "w_hidden_MoTr", "W_hidden_TrRi", "W_hidden_RiRi", "W_hidden_MeRi", "W_hidden_MMof", "W_hidden_Ri"]
df_weights_hidden.columns = ["weights"]
df_weights_hidden
# Out:
#                       0
# W_hidden_Plu  -1.332812
# W_hidden_TTra  0.501508
# W_hidden_TTrb  0.624317
# W_hidden_Tr   -0.016173
# W_hidden_RiTr  1.559336
# W_hidden_MoTr -0.023316
# W_hidden_MeTr -0.582481
# w_hidden_MoTr -0.023316
# W_hidden_TrRi -2.000460
# W_hidden_RiRi -0.657919
# W_hidden_MeRi -0.010056
# W_hidden_MMof -0.871741
# W_hidden_Ri   -0.761715

# %%
# plot the weights with plotly express
fig = px.bar(df_weights_hidden, x=df_weights_hidden.index, y=df_weights_hidden.columns,
              title= "weights_input_hidden", barmode='group',
              color = df_weights_hidden.to_numpy().flatten())
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 2
#       1 # plot the weights with plotly express
# ----> 2 fig = px.bar(df_weights_hidden, x=df_weights_hidden.index, y=df_weights_hidden.columns,
#       3               title= "weights_input_hidden", barmode='group',
#       4               color = df_weights_hidden.to_numpy().flatten())
#       5 fig.show()
#
# ...

# %%
# extract the weights of the output layers
W_output_a1a1 = autoencoder.get_layer("a1a1_output").get_weights()[0]
W_output_a1a2 = autoencoder.get_layer("a1a2_output").get_weights()[0]
W_output_a1a2a1 = autoencoder.get_layer("a1a2a1_output").get_weights()[0]
W_output_a1a2a2 = autoencoder.get_layer("a1a2a2_output").get_weights()[0]
W_output_a2a1 = autoencoder.get_layer("a2a1_output").get_weights()[0]
W_output_a2a1a1 = autoencoder.get_layer("a2a1a1_output").get_weights()[0]
W_output_a2a1a2 = autoencoder.get_layer("a2a1a2_output").get_weights()[0]
W_output_a2a2 = autoencoder.get_layer("a2a2_output").get_weights()[0]
